# %% [markdown]
# <a href="https://colab.research.google.com/github/gestionymetrologia-lang/ModelosAnaliticosUnicafam202607/blob/main/Condicionales_14_de_julio%2CManuel_Garc%C3%ADa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## VERIFICAR SI UNA PERSONA ES MAYOR DE EDAD

edad = int(input("Ingrese su edad: "))

if edad >= 18:
    print("La persona es mayor de edad.")
else:
    print("La persona es menor de edad.")
# Out:
# Ingrese su edad: 13
# La persona es menor de edad.

# %%
## VERIFICAR SI UN NÚMERO ES PAR O IMPAR

numero = int(input("Ingrese un número: "))

if numero % 2 == 0:
    print("El número es par.")
else:
    print("El número es impar.")
# Out:
# Ingrese un número: 677
# El número es impar.

# %%
## CLASIFICAR LA EDAD

edad = int(input("Ingrese la edad: "))

if edad >= 0 and edad <= 12:
    print("Niño")

elif edad >= 13 and edad <= 17:
    print("Adolescente")

elif edad >= 18 and edad <= 64:
    print("Adulto")

elif edad >= 65:
    print("Anciano")

else:
    print("Edad no válida")
# Out:
# Ingrese la edad: 0
# Niño

# %%
## DETERMINAR CUÁL NÚMERO ES MAYOR

numero1 = int(input("Ingrese el primer número: "))
numero2 = int(input("Ingrese el segundo número: "))

if numero1 > numero2:
    print("El número mayor es:", numero1)
    print("El número menor es:", numero2)

elif numero2 > numero1:
    print("El número mayor es:", numero2)
    print("El número menor es:", numero1)

else:
    print("Los dos números son iguales.")
# Out:
# Ingrese el primer número: 12
# Ingrese el segundo número: 12
# Los dos números son iguales.

# %%
## VERIFICAR UNA CONTRASEÑA

contraseña = input("Ingrese la contraseña: ")

if contraseña == "secreta123":
    print("Contraseña correcta.")

else:
    print("Contraseña incorrecta.")
# Out:
# Ingrese la contraseña: secreta1234
# Contraseña incorrecta.

# %%
## Verificar si un número está entre 1 y 100 y además es divisible por 5

numero = int(input("Ingrese un número: "))

if numero >= 1 and numero <= 100:

    if numero % 5 == 0:
        print("El número está entre 1 y 100 y es divisible por 5.")

    else:
        print("El número está entre 1 y 100, pero no es divisible por 5.")

else:
    print("El número está fuera del rango de 1 a 100.")
# Out:
# Ingrese un número: 355
# El número está fuera del rango de 1 a 100.
