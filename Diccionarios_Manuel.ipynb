# %% [markdown]
# <a href="https://colab.research.google.com/github/gestionymetrologia-lang/ModelosAnaliticosUnicafam202607/blob/main/Diccionarios_Manuel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## DICCIONARIOS

# %%
mi_diccionario= {
    "Nombre":"Manuel",
    "Ciudad de nacimiento":"Tunja",
    "Empresa":"Imcomelec Ingenieros"
}

# %%
# Acceder a los elementos del diccionario
print(mi_diccionario["Nombre"])
# Out:
# Manuel

# %%
# Modificar un valor del diccionario
mi_diccionario["Nombre"]="Manuel Jacinto"
print(mi_diccionario)
# Out:
# {'Nombre': 'Manuel Jacinto', 'Ciudad de nacimiento': 'Tunja', 'Empresa': 'Imcomelec Ingenieros'}

# %% [markdown]
# CONDICIONALES

# %%
# Crea un programa que determnine si una persona es mayor de edad o menor de edad
print("---VERIFICACIÓN DE EDAD---")
edad=int(input("Ingresa tu edad:"))
if edad<18:
  print(f"Eres menor de edad, tienes:[edad]")
else:
  print(f"Eres mayor de edad, tienes:[edad]")
# Out:
# ---VERIFICACIÓN DE EDAD---
# Ingresa tu edad:45
# Eres mayor de edad, tienes:[edad]

# %%
# Condicionales múltiples
nota=50
if nota>=80:
  if nota>=90:
    print("Excelente")
  elif nota>=80 and nota<=90:
    print("Aceptable")
else:
  print("Insuficiente")
# Out:
# Insuficiente

# %% [markdown]
# #
